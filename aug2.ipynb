# %% [markdown]
# <a href="https://colab.research.google.com/github/dokin0802/SinGAN/blob/master/aug2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np

import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.layers as layers

N_EPOCHS = 50
N_BATCH = 20

learning_rate = 0.001
dropout_rate = 0.5

np.random.seed(1)
tf.random.set_seed(1)


def create_model():
    model = keras.Sequential()
    model.add(layers.Conv2D(64, kernel_size=3, padding="SAME", activation='relu', 
                            input_shape=(150,150,3)))
    model.add(layers.MaxPool2D(padding='SAME'))

    model.add(layers.Conv2D(64, kernel_size=3, padding="SAME", activation='relu'))
    model.add(layers.MaxPool2D(padding='SAME'))

    model.add(layers.Conv2D(128, kernel_size=3, padding="SAME", activation='relu'))
    model.add(layers.MaxPool2D(padding='SAME'))

    model.add(layers.Conv2D(128, kernel_size=3, padding="SAME", activation='relu'))
    model.add(layers.MaxPool2D(padding='SAME'))

    model.add(layers.Flatten())
    model.add(layers.Dropout(dropout_rate))
    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))

    return model

# %%
train_dir = '/content/gdrive/MyDrive/architecture_aug/train'
validation_dir = '/content/gdrive/MyDrive/architecture_aug/val'
test_dir = '/content/gdrive/MyDrive/architecture_small/test'

# %%
import shutil
def split(img_list, val_count, train_path, val_path):
  val_files=[]
  for i in random.sample(img_list, val_count):
    val_files.append(i)
  
  train_files = [x for x in img_list if x not in val_files]

  for k in train_files:
    shutil.copy(k,train_path)
  for c in val_files:
    shutil.copy(c,val_path)

# %%
import os
import glob
import random

g_train_path= '/content/gdrive/MyDrive/architecture_aug/train/g'
r_train_path= '/content/gdrive/MyDrive/architecture_aug/train/r'
g_val_path= '/content/gdrive/MyDrive/architecture_aug/val/g'
r_val_path= '/content/gdrive/MyDrive/architecture_aug/val/r'

split(glob.glob('/content/gdrive/MyDrive/architecture_aug/org/g/*'), 50, g_train_path,g_val_path)
split(glob.glob('/content/gdrive/MyDrive/architecture_aug/org/r/*'), 50, r_train_path,r_val_path)

# %%
len(os.listdir(os.path.join(os.path.join('/content/gdrive/MyDrive/architecture_aug/val/g'))))
# Out:
# 50

# %%
import os
import glob
path = '/content/gdrive/MyDrive/architecture_aug/train'
g = glob.glob(path+'/g'+'/*')
r = glob.glob(path+'/r'+'/*')

def rename(files):
  if 'g' in files[0]:
    for i,f in enumerate(files):
      os.rename(f, os.path.join(path+"/g", 'g_' + '{0:03d}.jpg'.format(i)))
    g = glob.glob(path+'/g'+'/*')
  
  elif 'r' in files[0]:
    for i,f in enumerate(files):
      os.rename(f, os.path.join(path+"/r", 'r_' + '{0:03d}.jpg'.format(i)))
    r = glob.glob(path+'/r'+'/*')

# %%
rename(g)
rename(r)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-ecfc1afef0f6> in <cell line: 1>()
# ----> 1 rename(g)
#
# <ipython-input-6-ae826556fd6d> in rename(files)
#       8   if 'g' in files[0]:
#       9     for i,f in enumerate(files):
# ---> 10       os.rename(f, os.path.join(path+"/g", 'g_' + '{0:03d}.jpg'.format(i)))
#      11     g = glob.glob(path+'/g'+'/*')
#      12
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/architecture_aug/train/g/37.png' -> '/content/gdrive/MyDrive/architecture_aug/train/g/g_000.jpg'

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-624e0abb36fd> in <cell line: 1>()
# ----> 1 rename(r)
#
# <ipython-input-6-ae826556fd6d> in rename(files)
#       8   if 'g' in files[0]:
#       9     for i,f in enumerate(files):
# ---> 10       os.rename(f, os.path.join(path+"/g", 'g_' + '{0:03d}.jpg'.format(i)))
#      11     g = glob.glob(path+'/g'+'/*')
#      12
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/architecture_aug/train/r/49.png' -> '/content/gdrive/MyDrive/architecture_aug/train/g/g_000.jpg'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

train_datagen = ImageDataGenerator(rescale=1/255) 
test_datagen =  ImageDataGenerator(rescale=1/255)

# %%
train_generator = train_datagen.flow_from_directory(
                                    train_dir, 
                                    target_size=(150,150), 
                                    class_mode='binary',
                                    batch_size=N_BATCH   
                                )

validation_generator = test_datagen.flow_from_directory(
                                    validation_dir,
                                    target_size=(150,150), 
                                    class_mode='binary', 
                                    batch_size=N_BATCH   
                                )
# Test Set
test_generator = test_datagen.flow_from_directory(
                                    test_dir, 
                                    target_size=(150,150), 
                                    class_mode='binary', 
                                    batch_size=N_BATCH  
                                )
# Out:
# Found 400 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.

# %%
train_generator.class_indices # {'g': 0, 'dogs': 1}


len(train_generator), len(validation_generator), len(test_generator) # (100, 50, 50)


batch = train_generator.next() #2

len(batch), type(batch) #(2, tuple)

type(batch[0]), batch[0].shape # (numpy.ndarray, (20, 150, 150, 3))
# Out:
# (numpy.ndarray, (20, 150, 150, 3))

# %%
plt.figure(figsize=(10,10))
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.imshow(batch[0][i])
plt.show()

# %%
model = create_model()
model.compile(optimizer=keras.optimizers.Adam(learning_rate),
              loss='binary_crossentropy',  
              metrics=['accuracy'])


history= model.fit(train_generator, 
                    epochs=N_EPOCHS,
                    steps_per_epoch=len(train_generator),
                    validation_data=validation_generator, 
                    validation_steps = len(validation_generator)
                    )
# Out:
# Epoch 1/50
# 20/20 [==============================] - 4s 71ms/step - loss: 0.5517 - accuracy: 0.6975 - val_loss: 0.3007 - val_accuracy: 0.8500
# Epoch 2/50
# 20/20 [==============================] - 1s 63ms/step - loss: 0.1698 - accuracy: 0.9200 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 3/50
# 20/20 [==============================] - 1s 63ms/step - loss: 0.0147 - accuracy: 0.9975 - val_loss: 6.7628e-04 - val_accuracy: 1.0000
# Epoch 4/50
# 20/20 [==============================] - 1s 62ms/step - loss: 0.0112 - accuracy: 0.9975 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 5/50
# 20/20 [==============================] - 1s 73ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 4.6826e-06 - val_accuracy: 1.0000
# Epoch 6/50
# 20/20 [==============================] - 1s 63ms/step - loss: 3.3358e-04 - accuracy: 1.0000 - val_loss: 2.3639e-07 - val_accuracy: 1.0000
# Epoch 7/50
# 20/20 [==============================] - 1s 60ms/step - loss: 1.4881e-04 - accuracy: 1.0000 - val_loss: 2.2750e-06 - val_accuracy: 1.0000
# Epoch 8/50
# 20/20 [==============================] - 1s 61ms/step - loss: 1.0370e-04 - accuracy: 1.0000 - val_loss: 9.3952e-07 - val_accuracy: 1.0000
# Epoch 9/50
# 20/20 [==============================] - 1s 60ms/step - loss: 6.5194e-05 - accuracy: 1.0000 - val_loss: 4.3824e-07 - val_accuracy: 1.0000
# Epoch 10/50
# 20/20 [==============================] - 1s 62ms/step - loss: 6.1285e-06 - accuracy: 1.0000 - val_loss: 8.7828e-07 - val_accuracy: 1.0000
# Epoch 11/50
# 20/20 [==============================] - 1s 63ms/step - loss: 2.5631e-05 - accuracy: 1.0000 - val_loss: 2.3629e-07 - val_accuracy: 1.0000
# Epoch 12/50
# 20/20 [==============================] -
accuracy: 1.0000
# Epoch 40/50
# 20/20 [==============================] - 1s 62ms/step - loss: 4.0703e-06 - accuracy: 1.0000 - val_loss: 5.8401e-08 - val_accuracy: 1.0000
# Epoch 41/50
# 20/20 [==============================] - 1s 62ms/step - loss: 1.9273e-06 - accuracy: 1.0000 - val_loss: 7.7302e-08 - val_accuracy: 1.0000
# Epoch 42/50
# 20/20 [==============================] - 1s 62ms/step - loss: 2.1124e-05 - accuracy: 1.0000 - val_loss: 2.7897e-08 - val_accuracy: 1.0000
# Epoch 43/50
# 20/20 [==============================] - 1s 62ms/step - loss: 7.6371e-06 - accuracy: 1.0000 - val_loss: 7.0882e-08 - val_accuracy: 1.0000
# Epoch 44/50
# 20/20 [==============================] - 1s 64ms/step - loss: 2.2229e-06 - accuracy: 1.0000 - val_loss: 3.6443e-08 - val_accuracy: 1.0000
# Epoch 45/50
# 20/20 [==============================] - 1s 63ms/step - loss: 1.0865e-06 - accuracy: 1.0000 - val_loss: 3.1170e-08 - val_accuracy: 1.0000
# Epoch 46/50
# 20/20 [==============================] - 1s 61ms/step - loss: 2.0447e-05 - accuracy: 1.0000 - val_loss: 9.2772e-08 - val_accuracy: 1.0000
# Epoch 47/50
# 20/20 [==============================] - 1s 61ms/step - loss: 2.6722e-06 - accuracy: 1.0000 - val_loss: 1.3259e-07 - val_accuracy: 1.0000
# Epoch 48/50
# 20/20 [==============================] - 1s 61ms/step - loss: 3.3718e-06 - accuracy: 1.0000 - val_loss: 5.9225e-08 - val_accuracy: 1.0000
# Epoch 49/50
# 20/20 [==============================] - 1s 61ms/step - loss: 2.4608e-06 - accuracy: 1.0000 - val_loss: 3.0314e-08 - val_accuracy: 1.0000
# Epoch 50/50
# 20/20 [==============================] - 1s 63ms/step - loss: 7.0634e-06 - accuracy: 1.0000 - val_loss: 7.6529e-08 - val_accuracy: 1.0000

# %%
from keras.models import load_model
model.save('/content/gdrive/My Drive/archi_0.h5')

# %%
from keras.models import load_model
model = load_model('/content/gdrive/My Drive/archi_0.h5')
model.summary()

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-ce9171dbf527> in <cell line: 3>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 acc = history.history['acc']
#       4 val_acc = history.history['val_acc']
#       5 loss = history.history['loss']
#
# KeyError: 'acc'

# %%
model.evaluate(test_generator)
# Out:
# 5/5 [==============================] - 2s 374ms/step - loss: 10.3687 - accuracy: 0.4900
# [10.368738174438477, 0.49000000953674316]

# %%
train_gen = ImageDataGenerator(
    rescale = 1/255,
    rotation_range= 40,
    width_shift_range=0.2, #[-0.2, 0, +0.2]  ex)[-1, -0.5, 0, 0.5, 1]
    height_shift_range=0.2,
    shear_range=0.2, 
    zoom_range=0.2,
    horizontal_flip=True
)

test_gen = ImageDataGenerator(rescale=1/255)

# %%
train_generator = train_gen.flow_from_directory(train_dir,
                                                target_size=(150,150),
                                                class_mode='binary',
                                                batch_size=N_BATCH)

validation_generator = test_gen.flow_from_directory(validation_dir,
                                                target_size=(150,150),
                                                class_mode='binary',
                                                batch_size=N_BATCH)

test_generator = test_gen.flow_from_directory(test_dir,
                                                target_size=(150,150),
                                                class_mode='binary',
                                                batch_size=N_BATCH)
# Out:
# Found 400 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.

# %%
model.evaluate(train_generator)
# Out:
# 20/20 [==============================] - 3s 134ms/step - loss: 1.3491 - accuracy: 0.8400
# [1.3491259813308716, 0.8399999737739563]

# %%
import os
from tensorflow.keras.preprocessing.image import load_img, img_to_array

image_path = os.path.join(train_dir, 'g', '0 (2).png')
print(image_path)

img = load_img(image_path)
img
# Out:
# /content/gdrive/MyDrive/architecture_aug/train/g/0 (2).png
# <PIL.Image.Image image mode=RGB size=96x150 at 0x7F267D965180>

# %%
x = img_to_array(img)
x = x[np.newaxis, ...]
x.shape
# Out:
# (1, 150, 96, 3)

# %%
train_gen2 = ImageDataGenerator(
    # rescale = 1/255,
    rotation_range= 40,
    width_shift_range=0.2, #[-0.2, 0, +0.2]  ex)[-1, -0.5, 0, 0.5, 1]
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# %%
gen = train_gen2.flow(x, batch_size=1) 
plt.figure(figsize=(10,10))
for i in range(5):
    plt.subplot(5, 1, i+1)
    batch = gen.next()
    img = batch[0].astype('uint8')
    plt.imshow(img)
plt.show()

# %%
model = create_model()
model.compile(optimizer=keras.optimizers.Adam(learning_rate),
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 150, 150, 64)      1792
#
#  max_pooling2d_12 (MaxPoolin  (None, 75, 75, 64)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 75, 75, 64)        36928
#
#  max_pooling2d_13 (MaxPoolin  (None, 38, 38, 64)       0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 38, 38, 128)       73856
#
#  max_pooling2d_14 (MaxPoolin  (None, 19, 19, 128)      0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 19, 19, 128)       147584
#
#  max_pooling2d_15 (MaxPoolin  (None, 10, 10, 128)      0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 12800)             0
#
#  dropout_3 (Dropout)         (None, 12800)             0
#
#  dense_6 (Dense)             (None, 512)               6554112
#
#  dense_7 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 6,814,785
# Trainable params: 6,814,785
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(train_generator,
                epochs=N_EPOCHS,
                steps_per_epoch=len(train_generator),
                validation_data = validation_generator,
                validation_steps=len(validation_generator))
# Out:
# Epoch 1/50
# 20/20 [==============================] - 5s 150ms/step - loss: 0.6084 - accuracy: 0.6950 - val_loss: 0.2749 - val_accuracy: 0.9300
# Epoch 2/50
# 20/20 [==============================] - 3s 151ms/step - loss: 0.3462 - accuracy: 0.8350 - val_loss: 0.1556 - val_accuracy: 0.9300
# Epoch 3/50
# 20/20 [==============================] - 3s 149ms/step - loss: 0.1793 - accuracy: 0.9325 - val_loss: 0.0636 - val_accuracy: 1.0000
# Epoch 4/50
# 20/20 [==============================] - 3s 148ms/step - loss: 0.1467 - accuracy: 0.9425 - val_loss: 0.0305 - val_accuracy: 1.0000
# Epoch 5/50
# 20/20 [==============================] - 3s 147ms/step - loss: 0.0719 - accuracy: 0.9725 - val_loss: 0.0177 - val_accuracy: 0.9900
# Epoch 6/50
# 20/20 [==============================] - 3s 146ms/step - loss: 0.1261 - accuracy: 0.9525 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 7/50
# 20/20 [==============================] - 3s 150ms/step - loss: 0.0495 - accuracy: 0.9800 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 8/50
# 20/20 [==============================] - 3s 149ms/step - loss: 0.3275 - accuracy: 0.8750 - val_loss: 0.1770 - val_accuracy: 0.9200
# Epoch 9/50
# 20/20 [==============================] - 3s 146ms/step - loss: 0.2169 - accuracy: 0.9225 - val_loss: 0.0933 - val_accuracy: 1.0000
# Epoch 10/50
# 20/20 [==============================] - 3s 150ms/step - loss: 0.0707 - accuracy: 0.9850 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 11/50
# 20/20 [==============================] - 3s 149ms/step - loss: 0.3496 - accuracy: 0.8725 - val_loss: 0.2312 - val_accuracy: 0.9900
# Epoch 12/50
# 20/20 [==============================] - 3s 148ms/step - loss: 0.2614 - accuracy: 0.8975 - val_loss: 0.0404 - val_accuracy: 1.0000
# Epoch 13/50
# 20/20 [==============================] - 3s 147ms/step - loss: 0.1320 - accuracy: 0.9625 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 14/50
# 20/20 [==============================] - 3s 147ms/step - loss: 0.1444 - accuracy: 0.9475 - val_loss: 0.0398 - val_accuracy: 0.9800
# Epoch 15/50
# 20/20 [==============================] - 3s 159ms/step - loss: 0.1079 - accuracy: 0.9575 - val_loss: 0.0176 - val_accuracy: 1.0000
# Epoch 16/50
# 20/20 [==============================] - 3s 152ms/step - loss: 0.0286 - accuracy: 0.9850 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 17/50
# 20/20 [==============================] -