# %% [markdown]
# <a href="https://colab.research.google.com/github/dokin0802/SinGAN/blob/master/crawling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/mtinet/googleImageDownloader
# Out:
# Cloning into 'googleImageDownloader'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 37 (delta 12), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (37/37), 247.08 KiB | 4.19 MiB/s, done.

# %%
# %cd googleImageDownloader
# !python download_images.py -u urls.txt -o "/content/people"
# Out:
# [Errno 2] No such file or directory: 'googleImageDownloader'
# /content/googleImageDownloader
# [INFO] downloaded: /content/people/00000000.png
# [INFO] downloaded: /content/people/00000001.png
# [INFO] downloaded: /content/people/00000002.png
# [INFO] downloaded: /content/people/00000003.png
# [INFO] downloaded: /content/people/00000004.png
# [INFO] downloaded: /content/people/00000005.png
# [INFO] downloaded: /content/people/00000006.png
# [INFO] downloaded: /content/people/00000007.png
# [INFO] downloaded: /content/people/00000008.png
# [INFO] downloaded: /content/people/00000009.png
# [INFO] downloaded: /content/people/00000010.png
# [INFO] downloaded: /content/people/00000011.png
# [INFO] downloaded: /content/people/00000012.png
# [INFO] downloaded: /content/people/00000013.png
# [INFO] downloaded: /content/people/00000014.png
# [INFO] downloaded: /content/people/00000015.png
# [INFO] downloaded: /content/people/00000016.png
# [INFO] downloaded: /content/people/00000017.png
# ...

# %%
# !zip -r /content/00.zip /content/people
# Out:
#   adding: content/people/ (stored 0%)
#   adding: content/people/00000211.png (deflated 1%)
#   adding: content/people/00000551.png (deflated 4%)
#   adding: content/people/00000447.png (deflated 0%)
#   adding: content/people/00000089.png (deflated 4%)
#   adding: content/people/00000343.png (deflated 2%)
#   adding: content/people/00000033.png (deflated 2%)
#   adding: content/people/00000228.png (stored 0%)
#   adding: content/people/00000164.png (deflated 0%)
#   adding: content/people/00000148.png (deflated 10%)
#   adding: content/people/00000141.png (deflated 2%)
#   adding: content/people/00000357.png (deflated 0%)
#   adding: content/people/00000556.png (deflated 0%)
#   adding: content/people/00000298.png (deflated 1%)
#   adding: content/people/00000560.png (stored 0%)
#   adding: content/people/00000578.png (stored 0%)
#   adding: content/people/00000547.png (stored 0%)
#   adding: content/people/00000000.png (deflated 2%)
# ...
