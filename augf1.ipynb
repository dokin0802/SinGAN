# %% [markdown]
# <a href="https://colab.research.google.com/github/dokin0802/SinGAN/blob/master/augf1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np

import tensorflow as tf
import tensorflow.keras as keras
import tensorflow.keras.layers as layers

N_EPOCHS = 50
N_BATCH = 20

learning_rate = 0.001
dropout_rate = 0.5

np.random.seed(1)
tf.random.set_seed(1)


def create_model():
    model = keras.Sequential()
    model.add(layers.Conv2D(64, kernel_size=3, padding="SAME", activation='relu', 
                            input_shape=(150,150,3)))
    model.add(layers.MaxPool2D(padding='SAME'))

    model.add(layers.Conv2D(64, kernel_size=3, padding="SAME", activation='relu'))
    model.add(layers.MaxPool2D(padding='SAME'))

    model.add(layers.Conv2D(128, kernel_size=3, padding="SAME", activation='relu'))
    model.add(layers.MaxPool2D(padding='SAME'))

    model.add(layers.Conv2D(128, kernel_size=3, padding="SAME", activation='relu'))
    model.add(layers.MaxPool2D(padding='SAME'))

    model.add(layers.Flatten())
    model.add(layers.Dropout(dropout_rate))
    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))

    return model

# %%
train_dir = '/content/gdrive/MyDrive/architecture_aug/augf1'
validation_dir = '/content/gdrive/MyDrive/architecture_aug/augv1'
test_dir = '/content/gdrive/MyDrive/architecture_small/test'

# %%
import shutil
def split(img_list, val_count, train_path, val_path):
  val_files=[]
  for i in random.sample(img_list, val_count):
    val_files.append(i)
  
  train_files = [x for x in img_list if x not in val_files]

  for k in train_files:
    shutil.copy(k,train_path)
  for c in val_files:
    shutil.copy(c,val_path)

# %%
import os
import glob
import random

g_train_path= '/content/gdrive/MyDrive/architecture_aug/train/g'
r_train_path= '/content/gdrive/MyDrive/architecture_aug/train/r'
g_val_path= '/content/gdrive/MyDrive/architecture_aug/val/g'
r_val_path= '/content/gdrive/MyDrive/architecture_aug/val/r'

split(glob.glob('/content/gdrive/MyDrive/architecture_aug/org/g/*'), 50, g_train_path,g_val_path)
split(glob.glob('/content/gdrive/MyDrive/architecture_aug/org/r/*'), 50, r_train_path,r_val_path)

# %%
len(os.listdir(os.path.join(os.path.join('/content/gdrive/MyDrive/architecture_aug/val/g'))))
# Out:
# 50

# %%
import os
import glob
path = '/content/gdrive/MyDrive/architecture_aug/train'
g = glob.glob(path+'/g'+'/*')
r = glob.glob(path+'/r'+'/*')

def rename(files):
  if 'g' in files[0]:
    for i,f in enumerate(files):
      os.rename(f, os.path.join(path+"/g", 'g_' + '{0:03d}.jpg'.format(i)))
    g = glob.glob(path+'/g'+'/*')
  
  elif 'r' in files[0]:
    for i,f in enumerate(files):
      os.rename(f, os.path.join(path+"/r", 'r_' + '{0:03d}.jpg'.format(i)))
    r = glob.glob(path+'/r'+'/*')

# %%
rename(g)
rename(r)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-ecfc1afef0f6> in <cell line: 1>()
# ----> 1 rename(g)
#
# <ipython-input-6-ae826556fd6d> in rename(files)
#       8   if 'g' in files[0]:
#       9     for i,f in enumerate(files):
# ---> 10       os.rename(f, os.path.join(path+"/g", 'g_' + '{0:03d}.jpg'.format(i)))
#      11     g = glob.glob(path+'/g'+'/*')
#      12
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/architecture_aug/train/g/37.png' -> '/content/gdrive/MyDrive/architecture_aug/train/g/g_000.jpg'

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-624e0abb36fd> in <cell line: 1>()
# ----> 1 rename(r)
#
# <ipython-input-6-ae826556fd6d> in rename(files)
#       8   if 'g' in files[0]:
#       9     for i,f in enumerate(files):
# ---> 10       os.rename(f, os.path.join(path+"/g", 'g_' + '{0:03d}.jpg'.format(i)))
#      11     g = glob.glob(path+'/g'+'/*')
#      12
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/architecture_aug/train/r/49.png' -> '/content/gdrive/MyDrive/architecture_aug/train/g/g_000.jpg'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

train_datagen = ImageDataGenerator(rescale=1/255) 
test_datagen =  ImageDataGenerator(rescale=1/255)

# %%
train_generator = train_datagen.flow_from_directory(
                                    train_dir, 
                                    target_size=(150,150), 
                                    class_mode='binary',
                                    batch_size=N_BATCH   
                                )

validation_generator = test_datagen.flow_from_directory(
                                    validation_dir,
                                    target_size=(150,150), 
                                    class_mode='binary', 
                                    batch_size=N_BATCH   
                                )
# Test Set
test_generator = test_datagen.flow_from_directory(
                                    test_dir, 
                                    target_size=(150,150), 
                                    class_mode='binary', 
                                    batch_size=N_BATCH  
                                )
# Out:
# Found 204 images belonging to 2 classes.
# Found 51 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.

# %%
train_generator.class_indices # {'g': 0, 'dogs': 1}


len(train_generator), len(validation_generator), len(test_generator) # (100, 50, 50)


batch = train_generator.next() #2

len(batch), type(batch) #(2, tuple)

type(batch[0]), batch[0].shape # (numpy.ndarray, (20, 150, 150, 3))
# Out:
# (numpy.ndarray, (20, 150, 150, 3))

# %%
plt.figure(figsize=(10,10))
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.imshow(batch[0][i])
plt.show()

# %%
model = create_model()
model.compile(optimizer=keras.optimizers.Adam(learning_rate),
              loss='binary_crossentropy',  
              metrics=['accuracy'])


history= model.fit(train_generator, 
                    epochs=N_EPOCHS,
                    steps_per_epoch=len(train_generator),
                    validation_data=validation_generator, 
                    validation_steps = len(validation_generator)
                    )
# Out:
# Epoch 1/50
# 11/11 [==============================] - 33s 2s/step - loss: 0.2439 - accuracy: 0.9657 - val_loss: 0.1003 - val_accuracy: 0.9804
# Epoch 2/50
# 11/11 [==============================] - 2s 188ms/step - loss: 0.1045 - accuracy: 0.9804 - val_loss: 0.1028 - val_accuracy: 0.9804
# Epoch 3/50
# 11/11 [==============================] - 2s 190ms/step - loss: 0.1646 - accuracy: 0.9804 - val_loss: 0.1419 - val_accuracy: 0.9804
# Epoch 4/50
# 11/11 [==============================] - 2s 189ms/step - loss: 0.1325 - accuracy: 0.9804 - val_loss: 0.3006 - val_accuracy: 0.9804
# Epoch 5/50
# 11/11 [==============================] - 2s 188ms/step - loss: 0.4375 - accuracy: 0.9804 - val_loss: 0.1154 - val_accuracy: 0.9804
# Epoch 6/50
# 11/11 [==============================] - 2s 187ms/step - loss: 0.1683 - accuracy: 0.9804 - val_loss: 0.1409 - val_accuracy: 0.9804
# Epoch 7/50
# Epoch 46/50
# 11/11 [==============================] - 2s 187ms/step - loss: 0.0870 - accuracy: 0.9804 - val_loss: 0.1025 - val_accuracy: 0.9804
# Epoch 47/50
# 11/11 [==============================] - 2s 184ms/step - loss: 0.0927 - accuracy: 0.9804 - val_loss: 0.0977 - val_accuracy: 0.9804
# Epoch 48/50
# 11/11 [==============================] - 2s 186ms/step - loss: 0.0661 - accuracy: 0.9804 - val_loss: 0.1142 - val_accuracy: 0.9804
# Epoch 49/50
# 11/11 [==============================] - 2s 190ms/step - loss: 0.0706 - accuracy: 0.9804 - val_loss: 0.1174 - val_accuracy: 0.9804
# Epoch 50/50
# 11/11 [==============================] - 2s 188ms/step - loss: 0.0475 - accuracy: 0.9804 - val_loss: 0.1440 - val_accuracy: 0.9804

# %%
from keras.models import load_model
model.save('/content/gdrive/My Drive/archi_0.h5')

# %%
from keras.models import load_model
model = load_model('/content/gdrive/My Drive/archi_0.h5')
model.summary()

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-ce9171dbf527> in <cell line: 3>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 acc = history.history['acc']
#       4 val_acc = history.history['val_acc']
#       5 loss = history.history['loss']
#
# KeyError: 'acc'

# %%
model.evaluate(test_generator)
# Out:
# 5/5 [==============================] - 32s 8s/step - loss: 4.8750 - accuracy: 0.5000
# [4.874985218048096, 0.5]

# %%
train_gen = ImageDataGenerator(
    rescale = 1/255,
    rotation_range= 40,
    width_shift_range=0.2, #[-0.2, 0, +0.2]  ex)[-1, -0.5, 0, 0.5, 1]
    height_shift_range=0.2,
    shear_range=0.2, 
    zoom_range=0.2,
    horizontal_flip=True
)

test_gen = ImageDataGenerator(rescale=1/255)

# %%
train_generator = train_gen.flow_from_directory(train_dir,
                                                target_size=(150,150),
                                                class_mode='binary',
                                                batch_size=N_BATCH)

validation_generator = test_gen.flow_from_directory(validation_dir,
                                                target_size=(150,150),
                                                class_mode='binary',
                                                batch_size=N_BATCH)

test_generator = test_gen.flow_from_directory(test_dir,
                                                target_size=(150,150),
                                                class_mode='binary',
                                                batch_size=N_BATCH)
# Out:
# Found 204 images belonging to 2 classes.
# Found 51 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.

# %%
model.evaluate(train_generator)
# Out:
# 11/11 [==============================] - 3s 227ms/step - loss: 0.1736 - accuracy: 0.9804
# [0.173562690615654, 0.9803921580314636]

# %%
import os
from tensorflow.keras.preprocessing.image import load_img, img_to_array

image_path = os.path.join(train_dir, 'g', 'g (200).jpg')
print(image_path)

img = load_img(image_path)
img
# Out:
# /content/gdrive/MyDrive/architecture_aug/augf1/g/g (200).jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x1000 at 0x7F3BD01171F0>

# %%
x = img_to_array(img)
x = x[np.newaxis, ...]
x.shape
# Out:
# (1, 1000, 640, 3)

# %%
train_gen2 = ImageDataGenerator(
    # rescale = 1/255,
    rotation_range= 40,
    width_shift_range=0.2, #[-0.2, 0, +0.2]  ex)[-1, -0.5, 0, 0.5, 1]
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# %%
gen = train_gen2.flow(x, batch_size=1) 
plt.figure(figsize=(10,10))
for i in range(5):
    plt.subplot(5, 1, i+1)
    batch = gen.next()
    img = batch[0].astype('uint8')
    plt.imshow(img)
plt.show()

# %%
model = create_model()
model.compile(optimizer=keras.optimizers.Adam(learning_rate),
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 150, 150, 64)      1792
#
#  max_pooling2d_4 (MaxPooling  (None, 75, 75, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 75, 75, 64)        36928
#
#  max_pooling2d_5 (MaxPooling  (None, 38, 38, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 38, 38, 128)       73856
#
#  max_pooling2d_6 (MaxPooling  (None, 19, 19, 128)      0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 19, 19, 128)       147584
#
#  max_pooling2d_7 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  flatten_1 (Flatten)         (None, 12800)             0
#
#  dropout_1 (Dropout)         (None, 12800)             0
#
#  dense_2 (Dense)             (None, 512)               6554112
#
#  dense_3 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 6,814,785
# Trainable params: 6,814,785
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(train_generator,
                epochs=N_EPOCHS,
                steps_per_epoch=len(train_generator),
                validation_data = validation_generator,
                validation_steps=len(validation_generator))
# Out:
# Epoch 1/50
# 11/11 [==============================] - 5s 280ms/step - loss: 0.2161 - accuracy: 0.9510 - val_loss: 0.0994 - val_accuracy: 0.9804
# Epoch 2/50
# 11/11 [==============================] - 3s 270ms/step - loss: 0.1040 - accuracy: 0.9804 - val_loss: 0.2482 - val_accuracy: 0.9804
# Epoch 3/50
# 11/11 [==============================] - 3s 269ms/step - loss: 0.2885 - accuracy: 0.9804 - val_loss: 0.1450 - val_accuracy: 0.9804
# Epoch 4/50
# 11/11 [==============================] - 3s 267ms/step - loss: 0.1115 - accuracy: 0.9804 - val_loss: 0.1149 - val_accuracy: 0.9804
# Epoch 5/50
# 11/11 [==============================] - 3s 266ms/step - loss: 0.1278 - accuracy: 0.9804 - val_loss: 0.1047 - val_accuracy: 0.9804
# Epoch 6/50
# 11/11 [==============================] - 3s 269ms/step - loss: 0.1094 - accuracy: 0.9804 - val_loss: 0.0991 - val_accuracy: 0.9804
# Epoch 7/50
# 11/11 [==============================] - 3s 266ms/step - loss: 0.1137 - accuracy: 0.9804 - val_loss: 0.1029 - val_accuracy: 0.9804
# Epoch 8/50
# 11/11 [==============================] - 3s 272ms/step - loss: 0.1286 - accuracy: 0.9804 - val_loss: 0.1058 - val_accuracy: 0.9804
# Epoch 9/50
# 11/11 [==============================] - 3s 286ms/step - loss: 0.1051 - accuracy: 0.9804 - val_loss: 0.0991 - val_accuracy: 0.9804
# Epoch 10/50
# 11/11 [==============================] - 3s 273ms/step - loss: 0.1023 - accuracy: 0.9804 - val_loss: 0.1047 - val_accuracy: 0.9804
# Epoch 11/50
# 11/11 [==============================] - 3s 266ms/step - loss: 0.1081 - accuracy: 0.9804 - val_loss: 0.1027 - val_accuracy: 0.9804
# Epoch 12/50
# 11/11 [==============================] - 3s 265ms/step - loss: 0.1017 - accuracy: 0.9804 - val_loss: 0.1031 - val_accuracy: 0.9804
# Epoch 13/50
# 11/11 [==============================] - 3s 267ms/step - loss: 0.1018 - accuracy: 0.9804 - val_loss: 0.1239 - val_accuracy: 0.9804
# Epoch 14/50
# 11/11 [==============================] - 3s 267ms/step - loss: 0.0970 - accuracy: 0.9804 - val_loss: 0.1707 - val_accuracy: 0.9804
# Epoch 15/50
# 11/11 [==============================] - 3s 266ms/step - loss: 0.1317 - accuracy: 0.9804 - val_loss: 0.3451 - val_accuracy: 0.9804
# Epoch 16/50
# 11/11 [==============================] - 3s 268ms/step - loss: 0.3931 - accuracy: 0.9804 - val_loss: 0.4117 - val_accuracy: 0.9804
# Epoch 17/50
# 11/11 [==============================] - 3s 286ms/step - loss: 0.3674 - accuracy: 0.9804 - val_loss: 0.1013 - val_accuracy: 0.9804
# Epoch 18/50
# 11/11 [==============================] - 3s 262ms/step - loss: 0.1137 - accuracy: 0.9804 - val_loss: 0.1014 - val_accuracy: 0.9804
# Epoch 19/50
# 11/11 [==============================] - 3s 265ms/step - loss: 0.1193 - accuracy: 0.9804 - val_loss: 0.0989 - val_accuracy: 0.9804
# Epoch 20/50
# 11/11 [==============================] - 3s 263ms/step - loss: 0.1104 - accuracy: 0.9804 - val_loss: 0.0925 - val_accuracy: 0.9804
# Epoch 21/50
# 11/11 [==============================] - 3s 266ms/step - loss: 0.0922 - accuracy: 0.9804 - val_loss: 0.0958 - val_accuracy: 0.9804
# Epoch 22/50
# 11/11 [==============================] - 3s 267ms/step - loss: 0.1291 - accuracy: 0.9804 - val_loss: 0.0929 - val_accuracy: 0.9804
# Epoch 23/50
# 11/11 [==============================] - 3s 282ms/step - loss: 0.1055 - accuracy: 0.9804 - val_loss: 0.1042 - val_accuracy: 0.9804
# Epoch 24/50
# 11/11 [==============================] - 3s 265ms/step - loss: 0.1015 - accuracy: 0.9804 - val_loss: 0.1877 - val_accuracy: 0.9804
# Epoch 25/50
# 11/11 [==============================] - 3s 271ms/step - loss: 0.0917 - accuracy: 0.9804 - val_loss: 0.2331 - val_accuracy: 0.9804
# Epoch 26/50
# 11/11 [==============================] - 3s 287ms/step - loss: 0.0841 - accuracy: 0.9804 - val_loss: 2.9857 - val_accuracy: 0.9804
# Epoch 27/50
# 11/11 [==============================] - 3s 266ms/step - loss: 3.6837 - accuracy: 0.9755 - val_loss: 0.3787 - val_accuracy: 0.8039
# Epoch 28/50
# 11/11 [==============================] - 3s 264ms/step - loss: 0.2270 - accuracy: 0.9657 - val_loss: 0.1156 - val_accuracy: 0.9804
# Epoch 29/50
# 11/11 [==============================] - 3s 265ms/step - loss: 0.1079 - accuracy: 0.9804 - val_loss: 0.0899 - val_accuracy: 0.9804
# Epoch 30/50
# 11/11 [==============================] - 3s 268ms/step - loss: 0.1125 - accuracy: 0.9804 - val_loss: 0.0928 - val_accuracy: 0.9804
# Epoch 31/50
# 11/11 [==============================] - 3s 263ms/step - loss: 0.1011 - accuracy: 0.9804 - val_loss: 0.0931 - val_accuracy: 0.9804
# Epoch 32/50
# 11/11 [==============================] - 3s 270ms/step - loss: 0.1095 - accuracy: 0.9804 - val_loss: 0.0945 - val_accuracy: 0.9804
# Epoch 33/50
# 11/11 [==============================] - 3s 270ms/step - loss: 0.1156 - accuracy: 0.9804 - val_loss: 0.0956 - val_accuracy: 0.9804
# Epoch 34/50
# 11/11 [==============================] - 3s 264ms/step - loss: 0.1042 - accuracy: 0.9804 - val_loss: 0.0917 - val_accuracy: 0.9804
# Epoch 35/50
# 11/11 [==============================] - 3s 264ms/step - loss: 0.1078 - accuracy: 0.9804 - val_loss: 0.0913 - val_accuracy: 0.9804
# Epoch 36/50
# 11/11 [==============================] - 3s 268ms/step - loss: 0.1469 - accuracy: 0.9804 - val_loss: 0.0944 - val_accuracy: 0.9804
# Epoch 37/50
# 11/11 [==============================] - 3s 285ms/step - loss: 0.1110 - accuracy: 0.9804 - val_loss: 0.1116 - val_accuracy: 0.9804
# Epoch 38/50
# 11/11 [==============================] - 3s 268ms/step - loss: 0.1038 - accuracy: 0.9804 - val_loss: 0.1218 - val_accuracy: 0.9804
# Epoch 39/50
# 11/11 [==============================] - 3s 267ms/step - loss: 0.1418 - accuracy: 0.9804 - val_loss: 0.0944 - val_accuracy: 0.9804
# Epoch 40/50
# 11/11 [==============================] - 3s 267ms/step - loss: 0.1113 - accuracy: 0.9804 - val_loss: 0.0919 - val_accuracy: 0.9804
# Epoch 41/50
# 11/11 [==============================] - 3s 269ms/step - loss: 0.1058 - accuracy: 0.9804 - val_loss: 0.0925 - val_accuracy: 0.9804
# Epoch 42/50
# 11/11 [==============================] - 3s 269ms/step - loss: 0.1002 - accuracy: 0.9804 - val_loss: 0.0924 - val_accuracy: 0.9804
# Epoch 43/50
# 11/11 [==============================] - 3s 264ms/step - loss: 0.0973 - accuracy: 0.9804 - val_loss: 0.0950 - val_accuracy: 0.9804
# Epoch 44/50
# 11/11 [==============================] - 3s 264ms/step - loss: 0.1035 - accuracy: 0.9804 - val_loss: 0.1008 - val_accuracy: 0.9804
# Epoch 45/50
# 11/11 [==============================] - 3s 268ms/step - loss: 0.0991 - accuracy: 0.9804 - val_loss: 0.1001 - val_accuracy: 0.9804
# Epoch 46/50
# 11/11 [==============================] - 3s 268ms/step - loss: 0.0917 - accuracy: 0.9804 - val_loss: 0.1023 - val_accuracy: 0.9804
# Epoch 47/50
# 11/11 [==============================] - 3s 266ms/step - loss: 0.1176 - accuracy: 0.9804 - val_loss: 0.0958 - val_accuracy: 0.9804
# Epoch 48/50
# 11/11 [==============================] - 3s 266ms/step - loss: 0.1154 - accuracy: 0.9804 - val_loss: 0.1007 - val_accuracy: 0.9804
# Epoch 49/50
# 11/11 [==============================] - 3s 267ms/step - loss: 0.1046 - accuracy: 0.9804 - val_loss: 0.1035 - val_accuracy: 0.9804
# Epoch 50/50
# 11/11 [==============================] - 3s 269ms/step - loss: 0.0988 - accuracy: 0.9804 - val_loss: 0.0979 - val_accuracy: 0.9804

# %%
model.evaluate(test_generator)
# Out:
# 5/5 [==============================] - 2s 360ms/step - loss: 2.3373 - accuracy: 0.5000
# [2.3372864723205566, 0.5]
