# %% [markdown]
# <a href="https://colab.research.google.com/github/dokin0802/SinGAN/blob/master/DA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import os
from PIL import Image
import sys

print("Process Start.")

start_time = time.time()

# 부풀릴 이미지 입력
image_filename = sys.argv[1]

# 결과 저장 폴더 생성
out_dir ="augmentation_10"
if out_dir not in os.listdir():
    os.mkdir(out_dir)

# 부풀릴 이미지 파일 불러오기
image = Image.open("g_326.jpg")
Xdim, Ydim = image.size

# 저장된 파일 개수 카운터
COUNT = 1

# 원본 저장
# 저장할 파일의 이름을 입력합니다.
temp_new_file_name = "%05d.jpg" %COUNT
# 카운트를 1 증가시킵니다.
COUNT += 1
# 원본 이미지를 저장합니다.
image.save(out_dir + "/" + temp_new_file_name)
image.close()

# 출력 파일명을 저장할 리스트를 만듭니다.
FILELIST = [temp_new_file_name]

# 폴더 내의 이미지를 모두 읽어와 좌우대칭을 저장합니다. 2의 1승
for i in range(len(FILELIST)):
    # 파일을 불러옵니다.
    image = Image.open(out_dir + "/" + FILELIST[i])
    # 변환된 파일을 저장하기 위해 새로운 이름을 지정합니다.
    new_temp_name = "%05d.jpg" %COUNT
    # 사진이 한 장 만들어질때마다 count를 1씩 증가시킵니다.
    COUNT += 1
    # 이미지를 좌우 반전합니다.
    image = image.transpose(Image.FLIP_LEFT_RIGHT)
    # 좌우 반전된 이미지를 저장합니다.
    image.save(out_dir + "/" + new_temp_name)
    image.close()
    # 출력 파일명을 리스트에 저장합니다.
    FILELIST.append(new_temp_name)

# 리스트 안의 이미지를 모두 읽어와 상하대칭을 저장합니다. 2의 2승
for i in range(len(FILELIST)):
    # 파일을 불러옵니다.
    image = Image.open(out_dir + "/" + FILELIST[i])
    # 변환된 파일을 저장하기 위해 새로운 이름을 지정합니다.
    new_temp_name = "%05d.jpg" % COUNT
    # 사진이 한 장 만들어질때마다 count를 1씩 증가시킵니다.
    COUNT += 1
    # 이미지를 상하 반전합니다.
    image = image.transpose(Image.FLIP_TOP_BOTTOM)
    # 상하 반전된 이미지를 저장합니다.
    image.save(out_dir + "/" + new_temp_name)
    image.close()
    # 출력 파일명을 리스트에 저장합니다.
    FILELIST.append(new_temp_name)

# 리스트 안의 이미지를 모두 읽어와 흑백버전을 저장합니다. 2의 3승
for i in range(len(FILELIST)):
    # 파일을 불러옵니다.
    image = Image.open(out_dir + "/" + FILELIST[i])
    # 변환된 파일을 저장하기 위해 새로운 이름을 지정합니다.
    new_temp_name = "%05d.jpg" % COUNT
    # 사진이 한 장 만들어질때마다 count를 1씩 증가시킵니다.
    COUNT += 1
    # 이미지를 흑백으로 만듭니다.
    image = image.convert('1')
    # 흑백으로 변환된 이미지를 저장합니다.
    image.save(out_dir + "/" + new_temp_name)
    image.close()
    # 출력 파일명을 리스트에 저장합니다.
    FILELIST.append(new_temp_name)

# 리스트 안의 이미지를 모두 읽어와 1도씩 회전합니다. 2의 3승 * 180
for el in FILELIST:
    for i in range(180):
        # 깔끔하게 1,000장만 만듭시다.
        # 결과물이 1000개를 넘어서면 코드를 종료합니다.
        if COUNT > 100:
            break
        # 파일을 불러옵니다.
        image = Image.open(out_dir + "/" + el)
        # 변환된 파일을 저장하기 위해 새로운 이름을 지정합니다.
        new_temp_name = "%05d.jpg" % COUNT
        # 사진이 한 장 만들어질때마다 count를 1씩 증가시킵니다.
        COUNT += 1
        # 사진을 회전시킵니다.
        image = image.rotate(i+1)
        # 간혹 이미지 크기가 변경된다는 이야기가 있어 resize()를 실행합니다.
        image = image.resize((Xdim, Ydim))
        # 회전 된 이미지를 저장합니다.
        image.save(out_dir + "/" + new_temp_name)
        image.close()

print("Process Done.")

end_time = time.time()
print("The Job Took " + str(end_time - start_time) + " seconds.")
# Out:
# Process Start.
# Process Done.
# The Job Took 4.305953741073608 seconds.

# %%
# !zip -r /content/10.zip /content/augmentation_10
# Out:
#   adding: content/augmentation_10/ (stored 0%)
#   adding: content/augmentation_10/00010.jpg (deflated 2%)
#   adding: content/augmentation_10/00067.jpg (deflated 3%)
#   adding: content/augmentation_10/00015.jpg (deflated 2%)
#   adding: content/augmentation_10/00013.jpg (deflated 2%)
#   adding: content/augmentation_10/00083.jpg (deflated 2%)
#   adding: content/augmentation_10/00096.jpg (deflated 2%)
#   adding: content/augmentation_10/00066.jpg (deflated 3%)
#   adding: content/augmentation_10/00092.jpg (deflated 2%)
#   adding: content/augmentation_10/00095.jpg (deflated 2%)
#   adding: content/augmentation_10/00031.jpg (deflated 2%)
#   adding: content/augmentation_10/00036.jpg (deflated 3%)
#   adding: content/augmentation_10/00030.jpg (deflated 2%)
#   adding: content/augmentation_10/00048.jpg (deflated 3%)
#   adding: content/augmentation_10/00080.jpg (deflated 2%)
#   adding: content/augmentation_10/00012.jpg (deflated 2%)
#   adding: content/augmentation_10/00037.jpg (deflated 3%)
#   adding: content/augmentation_10/00093.jpg (deflated 2%)
#   adding: content/augmentation_10/00008.jpg (deflated 1%)
#   adding: content/augmentation_10/00018.jpg (deflated 2%)
#   adding: content/augmentation_10/00085.jpg (deflated 2%)
#   adding: content/augmentation_10/00065.jpg (deflated 3%)
#   adding: content/augmentation_10/00089.jpg (deflated 2%)
#   adding: content/augmentation_10/00082.jpg (deflated 2%)
#   adding: content/augmentation_10/00087.jpg (deflated 2%)
#   adding: content/augmentation_10/00086.jpg (deflated 2%)
#   adding: content/augmentation_10/00061.jpg (deflated 3%)
#   adding: content/augmentation_10/00041.jpg (deflated 3%)
#   adding: content/augmentation_10/00058.jpg (deflated 3%)
#   adding: content/augmentation_10/00014.jpg (deflated 2%)
#   adding: content/augmentation_10/00056.jpg (deflated 3%)
#   adding: content/augmentation_10/00076.jpg (deflated 2%)
#   adding: content/augmentation_10/00094.jpg (deflated 2%)
#   adding: content/augmentation_10/00091.jpg (deflated 2%)
#   adding: content/augmentation_10/00040.jpg (deflated 3%)
#   adding: content/augmentation_10/00059.jpg (deflated 3%)
#   adding: content/augmentation_10/00023.jpg (deflated 2%)
#   adding: content/augmentation_10/00077.jpg (deflated 2%)
#   adding: content/augmentation_10/00071.jpg (deflated 2%)
#   adding: content/augmentation_10/00081.jpg (deflated 2%)
#   adding: content/augmentation_10/00049.jpg (deflated 3%)
#   adding: content/augmentation_10/00055.jpg (deflated 3%)
#   adding: content/augmentation_10/00002.jpg (deflated 3%)
#   adding: content/augmentation_10/00025.jpg (deflated 2%)
#   adding: content/augmentation_10/00043.jpg (deflated 3%)
#   adding: content/augmentation_10/00006.jpg (deflated 1%)
#   adding: content/augmentation_10/00053.jpg (deflated 4%)
#   adding: content/augmentation_10/00004.jpg (deflated 2%)
#   adding: content/augmentation_10/00069.jpg (deflated 3%)
#   adding: content/augmentation_10/00035.jpg (deflated 3%)
#   adding: content/augmentation_10/00026.jpg (deflated 2%)
#   adding: content/augmentation_10/00039.jpg (deflated 3%)
#   adding: content/augmentation_10/00042.jpg (deflated 3%)
#   adding: content/augmentation_10/00060.jpg (deflated 3%)
#   adding: content/augmentation_10/00068.jpg (deflated 2%)
#   adding: content/augmentation_10/00090.jpg (deflated 2%)
#   adding: content/augmentation_10/00028.jpg (deflated 2%)
#   adding: content/augmentation_10/00011.jpg (deflated 2%)
#   adding: content/augmentation_10/00017.jpg (deflated 2%)
#   adding: content/augmentation_10/00054.jpg (deflated 3%)
#   adding: content/augmentation_10/00021.jpg (deflated 2%)
#   adding: content/augmentation_10/00075.jpg (deflated 2%)
#   adding: content/augmentation_10/00062.jpg (deflated 3%)
#   adding: content/augmentation_10/00078.jpg (deflated 2%)
#   adding: content/augmentation_10/00072.jpg (deflated 2%)
#   adding: content/augmentation_10/00046.jpg (deflated 3%)
#   adding: content/augmentation_10/00033.jpg (deflated 2%)
#   adding: content/augmentation_10/00097.jpg (deflated 2%)
#   adding: content/augmentation_10/00084.jpg (deflated 2%)
#   adding: content/augmentation_10/00079.jpg (deflated 2%)
#   adding: content/augmentation_10/00032.jpg (deflated 3%)
#   adding: content/augmentation_10/00064.jpg (deflated 3%)
#   adding: content/augmentation_10/00047.jpg (deflated 3%)
#   adding: content/augmentation_10/00005.jpg (deflated 2%)
#   adding: content/augmentation_10/00007.jpg (deflated 1%)
#   adding: content/augmentation_10/00099.jpg (deflated 2%)
#   adding: content/augmentation_10/00100.jpg (deflated 2%)
#   adding: content/augmentation_10/00022.jpg (deflated 2%)
#   adding: content/augmentation_10/00044.jpg (deflated 3%)
#   adding: content/augmentation_10/00057.jpg (deflated 3%)
#   adding: content/augmentation_10/00019.jpg (deflated 2%)
#   adding: content/augmentation_10/00029.jpg (deflated 2%)
#   adding: content/augmentation_10/00016.jpg (deflated 2%)
#   adding: content/augmentation_10/00098.jpg (deflated 3%)
#   adding: content/augmentation_10/00038.jpg (deflated 3%)
#   adding: content/augmentation_10/00009.jpg (deflated 2%)
#   adding: content/augmentation_10/00045.jpg (deflated 3%)
#   adding: content/augmentation_10/00051.jpg (deflated 3%)
#   adding: content/augmentation_10/00020.jpg (deflated 2%)
#   adding: content/augmentation_10/00074.jpg (deflated 2%)
#   adding: content/augmentation_10/00003.jpg (deflated 2%)
#   adding: content/augmentation_10/00070.jpg (deflated 2%)
#   adding: content/augmentation_10/00088.jpg (deflated 2%)
#   adding: content/augmentation_10/00024.jpg (deflated 2%)
#   adding: content/augmentation_10/00034.jpg (deflated 3%)
#   adding: content/augmentation_10/00027.jpg (deflated 2%)
#   adding: content/augmentation_10/00050.jpg (deflated 3%)
#   adding: content/augmentation_10/00052.jpg (deflated 3%)
#   adding: content/augmentation_10/00001.jpg (deflated 3%)
#   adding: content/augmentation_10/00073.jpg (deflated 2%)
#   adding: content/augmentation_10/00063.jpg (deflated 3%)
